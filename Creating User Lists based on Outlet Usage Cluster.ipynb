# %%
#import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# <h1> Orders Export Preparation </h1>

# %% [markdown]
# Importing and cleaning orders data

# %%
#import dataframe of offers used from Jan 2019 - May 4 2020
orders_df = pd.read_csv('orders 2019_01_to_2020_05_04.csv')

#extract outlet_id, phone only
orders_df = orders_df[['outlet_id','phone','outlet_name']]

#remove NULLS
orders_df.count()
orders_df.dropna(subset=['phone', 'outlet_id'], inplace=True)
orders_df.reset_index(drop=True, inplace = True)
#the df should have outlet_ids and phone numbers only at this point, make sure data types are consistent
orders_df['phone'] = orders_df['phone'].astype(int)

# %% [markdown]
# <h1>Outlets Export Preparation</h1>

# %% [markdown]
# Calculate outlets' distance from target outlet

# %%
#select target outlet to use and input longitude latitude as variables
target_lat = 25.28744
target_long =  51.540345

# %%
#import outlets data outlet_id, outlet_name,lat, long columns
outlets_df = pd.read_csv('Outlets_2020_05_04.csv', header = 0,
                         encoding= 'unicode_escape')
outlets_df = outlets_df[['outlet_id','outlet_name','lat','long']]
outlets_df.head()
# Out:
#    outlet_id                                   outlet_name        lat  \
# 0        880  Alghais Diving Center - Banana Island Resort  25.296362
# 1       2074                   Koshari Station - Al Wakrah  25.179781
# 2        243                  Barahat Al Wakrah Restaurant  25.172543
# 3       1013                Royal Tandoor - Souq Al Wakrah  25.168986
# 4       1879                         Smaisma Cafe - Wakrah  25.170867
#
#         long
# 0  51.645839
# 1  51.611892
# 2  51.611340
# 3  51.610198
# 4  51.609648

# %% [markdown]
# <h1>Calculating Distances from the Target Outlet </h1>

# %%
#calculate distances of the outlets from target outlet, add column distance from target (eudlidean) in km
#define haversine
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km

#finally, calculate
outlets_df['dist_km'] = [haversine(target_long,target_lat,outlets_df.long[i],outlets_df.lat[i]) for i in range(len(outlets_df))]

# %% [markdown]
# <h1>Filtering numbers who ordered within 5 km of the target outlet</h1>

# %%
#we use 6 km due to differences road distances (std of 3) output eligible for delivery, if not eligible for delivery
delivery_elig = outlets_df[outlets_df['dist_km'] <= 5]
delivery_elig = delivery_elig[['outlet_id','outlet_name','dist_km','lat','long']]
delivery_elig
# Out:
#      outlet_id                                        outlet_name   dist_km  \
# 42        1706                               Red Salon For Ladies  4.415014
# 43         418                        Titanium Tint - Old Airport  4.341307
# 44         601                       Baskin Robbins - Old Airport  4.320248
# 45         643                        Dunkin Donuts - Old Airport  4.320248
# 46        1895                         Bun Al Ameed - Old Airport  4.301717
# 47         567                       Baskin Robbins - FFC Airport  3.298865
# 48        1005                     Bombay Chowpatty - Old Airport  3.277518
# 49         628                        Dunkin Donuts - FFC Airport  3.285412
# 50        1021                                      Tandoor - FFC  3.299597
# 51         714                     Bodylines at Oryx Rotana Hotel  2.551827
# 52         712                                 Choices Restaurant  2.551827
# 53         713                                          Jazz Club  2.551827
# 54        1503                                  Oryx Rotana Hotel  2.551827
# 55         685                              The Cellar Restaurant  2.551827
# 56        1798                          Filli Cafe - Matar Qadeem  4.275060
# 62         381                                Brite Dental Centre  4.553164
# 63        2081                                        Atrium Cafe  1.862483
# 64        2080                                  Violet Restaurant  1.862483
# 65        2082                                           Vip Pool  1.862483
# 73        1476                                Caruso's Restaurant  2.455262
# 88        2125  Shore Time Kainang Pinoy Restaurant - Mathar Q...  4.263414
# 530  25.291459  51.498322
# 531  25.291459  51.498322
# 532  25.265367  51.498223
# 538  25.273287  51.497212
# 539  25.291394  51.497138
# 542  25.273548  51.496876
# 543  25.281079  51.496630
# 544  25.295290  51.496541
# 545  25.289049  51.496280
# 546  25.289049  51.496280
# 547  25.289049  51.496280
# 548  25.282850  51.496243
# 550  25.273287  51.495905
# 552  25.282362  51.495428
# 553  25.273454  51.495049
# 554  25.273049  51.494436
# 555  25.273049  51.494436
# 556  25.273335  51.494269
# 560  25.273161  51.493240
#
# [369 rows x 5 columns]

# %%
#map data
import folium
latitude = 25.2854
longitude = 51.5310
eligible = folium.Map(location=[latitude, longitude], zoom_start=11) 

for lat, long, dist, label in zip(delivery_elig['lat'], delivery_elig['long'], delivery_elig['dist_km'], delivery_elig['outlet_name']):
    label = folium.Popup(label, parse_html=True)
    if dist <0.00001:
        color = 'red'
    else:
        color = 'green'
    folium.features.CircleMarker(
        [lat, long],
        radius=5,
        color= color,
        fill = True,
        popup = label,
        fill_color='green',
    ).add_to(eligible)
    

# display map

eligible
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#merge with orders export to find phone numbers who ordered from eligible outlets, Nan under dist_km means not <10km
target_user = orders_df.merge(delivery_elig[['outlet_id','dist_km']],on="outlet_id", how = 'left')

#select only numbers that are eligible and remove nan from dist_km
target_user = target_user.dropna(subset=['dist_km'])
target_user
# Out:
#         outlet_id        phone  \
# 5             985  97466952011
# 7             175  97430219199
# 8             974  97450561620
# 9             988  97430881911
# 10            981  97433254876
# 11            974  97433666219
# 12            955  97455117381
# 13           2144  97455104880
# 15           2144  97455104880
# 17            974  97455807360
# 21            985  97450707131
# 22            167  97450333526
# 23            167  97433522013
# 24           1475  97466740262
# 25           1475  97466740262
# 29            113  97450016128
# 32            985  97455282944
# 33           2156  97450809606
# 34           2156  97450809606
# 43           1912  97450247173
# 44            184  97466331039
# 45            974  97455482968
# 46            985  97450705689
# 47           2144  97455146578
# 49            717  97455696193
# 54            985  97470564470
# 55            184  97455463449
# 56            717  97450150329
# 58            717  97450150329
# 60            184  97433833412
# ...           ...          ...
# 340072        703  97466133338
# 340073        269  97450067772
# 340075        302  97466422389
# 340080        877  97466656203
# 340084         62  97455517728
# 340086         62  97455517728
# 340091        601  97466688178
# 340096        280  97455942257
# 340097        280  97455942257
# 340103        280  97433655923
# 340110        643  97470535765
# 340112        601  97470535765
# 340113        601  97470535765
# 340127        304  97455115596
# 340128        304  97455115596
# 340149        575  97433818980
# 340152        881  97430151500
# 340156        743  97433005884
# 340157        743  97433005884
# 340166         99  97433884464
# 340167         65  97466672044
# 340168         65  97466672044
# 340169         65  97466672044
# 340172         49  97455251652
# 340174        641  97455345519
# 340176         62  97466338477
# 340184        472  97474077221
# 340187        577  97455570258
# 340188         62  97455570258
# 340192        567  97433165654
#
#                                              outlet_name   dist_km
# 5                         Papa John's - Old Airport Area  4.258450
# 7                                    Papa John's - Emadi  0.819486
# 8                               Papa John's - Salwa Road  4.767178
# 9                            Papa John's - Umm Salal Ali  0.819151
# 10                             Papa John's - Ezdan Tower  3.971105
# 11                              Papa John's - Salwa Road  4.767178
# 12            The Coffee Bean & Tea Leaf - Kidney Center  4.489575
# 13                       Maison de Sushi - Tornado Tower  3.725356
# 15                       Maison de Sushi - Tornado Tower  3.725356
# 17                              Papa John's - Salwa Road  4.767178
# 21                        Papa John's - Old Airport Area  4.258450
# 22                               Bo's Coffee - Bin Omran  4.137267
# 23                               Bo's Coffee - Bin Omran  4.137267
# 24                                     Naanaa Restaurant  4.199284
# 25                                     Naanaa Restaurant  4.199284
# 29                            Zaffran Cafe - Al Muntazah  2.919701
# 32                        Papa John's - Old Airport Area  4.258450
# 33                                Pistachio's Restaurant  3.452529
# 34                                Pistachio's Restaurant  3.452529
# 43                                Sultani Indian Cuisine  3.657220
# 44                                    Seasons Restaurant  0.535241
# 45                              Papa John's - Salwa Road  4.767178
# 46                        Papa John's - Old Airport Area  4.258450
# 47                       Maison de Sushi - Tornado Tower  3.725356
# 49                               Gerry's Grill - Al Nasr  4.891031
# 54                        Papa John's - Old Airport Area  4.258450
# 55                                    Seasons Restaurant  0.535241
# 56                               Gerry's Grill - Al Nasr  4.891031
# 58                               Gerry's Grill - Al Nasr  4.891031
# 60                                    Seasons Restaurant  0.535241
# ...                                                  ...       ...
# 340072  Caffe Vergnano 1882 - Qatar Handball Association  4.221530
# 340073                                 Burger King - QHA  4.233477
# 340075                     Applebee's - City Center Mall  4.337589
# 340080            Cinnabon - Al Mana Plaza; Bin Mahmoud   3.137373
# 340084                              Biella - City Center  4.372116
# 340086                              Biella - City Center  4.372116
# 340091                      Baskin Robbins - Old Airport  4.320248
# 340096                             Burger King - Al Nasr  3.496949
# 340097                             Burger King - Al Nasr  3.496949
# 340103                             Burger King - Al Nasr  3.496949
# 340110                       Dunkin Donuts - Old Airport  4.320248
# 340112                      Baskin Robbins - Old Airport  4.320248
# 340113                      Baskin Robbins - Old Airport  4.320248
# 340127                    Applebee's - Qatar Sports Club  4.210661
# 340128                    Applebee's - Qatar Sports Club  4.210661
# 340149                      Baskin Robbins - Royal Plaza  3.916123
# 340152                                Domino's - Al Nasr  4.635562
# 340156                                   Zahr El-Laymoun  3.406866
# 340157                                   Zahr El-Laymoun  3.406866
# 340166                          Emirgan Sutis - Al Hilal  3.092909
# 340167                                    Biella - Pearl  3.760650
# 340168                                    Biella - Pearl  3.760650
# 340169                                    Biella - Pearl  3.760650
# 340172                    Bread And Bagels - Beach Tower  4.878803
# 340174                          Dunkin Donuts - Munthaza  2.068849
# 340176                              Biella - City Center  4.372116
# 340184                                Al Maha Restaurant  3.159347
# 340187                 Baskin Robbins - City Center Mall  4.311836
# 340188                              Biella - City Center  4.372116
# 340192                      Baskin Robbins - FFC Airport  3.298865
#
# [132179 rows x 4 columns]

# %% [markdown]
# <h1>Final List Filtering: Select ONLY OOREDOO and REMOVE DUPLICATES</h1>

# %%
#import registration export
registration = pd.read_csv('registered_customers 2020.05.04.csv')
registration = registration[['phone','network']]

#merge target user data frame with registered export to find ooredoo numbers
target_user = target_user.merge(registration,on="phone",copy = False)

#select only numbers that are ooredoo
target_user = target_user[target_user['network'] == 'ooredoo']

target_user
# Out:
#         outlet_id        phone                           outlet_name  \
# 0             985  97466952011        Papa John's - Old Airport Area
# 1            1922  97466952011                Lamazani Grill - Najma
# 2             175  97430219199                   Papa John's - Emadi
# 6       4.258450  ooredoo
# 7       4.767178  ooredoo
# 8       3.399316  ooredoo
# 9       3.399316  ooredoo
# 10      0.819151  ooredoo
# 11      0.819151  ooredoo
# 12      4.314418  ooredoo
# 13      0.819151  ooredoo
# 14      3.971105  ooredoo
# 15      3.971105  ooredoo
# 16      4.242709  ooredoo
# 17      4.242709  ooredoo
# 18      4.242709  ooredoo
# 19      3.971105  ooredoo
# 20      4.003709  ooredoo
# 21      4.003709  ooredoo
# 22      4.359424  ooredoo
# 23      3.760650  ooredoo
# 24      3.760650  ooredoo
# 25      3.971105  ooredoo
# 26      4.359424  ooredoo
# 27      4.359424  ooredoo
# 28      4.337589  ooredoo
# 29      4.337589  ooredoo
# ...          ...      ...
# 132340  4.177910  ooredoo
# 132344  0.769824  ooredoo
# 132345  0.769824  ooredoo
# 132346  3.574422  ooredoo
# 132347  4.337421  ooredoo
# 132348  4.233477  ooredoo
# 132349  4.233477  ooredoo
# 132350  4.635562  ooredoo
# 132351  3.453832  ooredoo
# 132352  4.635562  ooredoo
# 132353  4.337421  ooredoo
# 132354  3.453832  ooredoo
# 132355  3.298865  ooredoo
# 132356  3.298865  ooredoo
# 132357  3.482060  ooredoo
# 132358  3.482060  ooredoo
# 132359  3.482060  ooredoo
# 132361  4.307156  ooredoo
# 132362  4.307156  ooredoo
# 132363  4.307156  ooredoo
# 132364  4.311836  ooredoo
# 132365  4.316575  ooredoo
# 132366  4.316575  ooredoo
# 132367  3.453832  ooredoo
# 132368  3.482060  ooredoo
# 132369  4.003709  ooredoo
# 132370  4.210661  ooredoo
# 132371  4.210661  ooredoo
# 132372  4.210661  ooredoo
# 132373  3.496949  ooredoo
#
# [130398 rows x 5 columns]

# %%
#remove duplicates and select phone numbers only
target_user.drop_duplicates(subset ="phone", keep = False, inplace = True)
target_user = target_user[['phone']]
#save to csv
target_user.to_csv(r'Targeting Maxill.csv', index = False)
target_user
# Out:
#               phone
# 71      97455117381
# 102     97450707131
# 138     97433522013
# 157     97450016128
# 158     97455282944
# 169     97466331039
# 200     97470564470
# 201     97455463449
# 251     97433833412
# 266     97455389008
# 317     97455283689
# 328     97455257947
# 495     97455471395
# 809     97433660104
# 876     97466282245
# 993     97450935107
# 1043    97433499855
# 1139    97433362980
# 1171    97455135086
# 1191    97466899939
# 1224    97433814463
# 1246    97450096688
# 1300    97466797909
# 1490    97455808283
# 1587    97466467251
# 1588    97466648565
# 1614    97466531413
# 1798    97466068067
# 1945    97455828511
# 1959    97433425528
# ...             ...
# 132306  97477595599
# 132307  97433022062
# 132317  97455107689
# 132324  97433108834
# 132327  97433135550
# 132328  97477947193
# 132329  97477750339
# 132330  97466401031
# 132331  97433289376
# 132334  97455623692
# 132335  97466111017
# 132336  97450477509
# 132337  97433061692
# 132338  97470360188
# 132339  97455260900
# 132340  97433818348
# 132346  97466937770
# 132347  97450374449
# 132350  97450022993
# 132351  97477992767
# 132352  97450013868
# 132353  97433654101
# 132354  97466083885
# 132361  97433280056
# 132362  97433547968
# 132363  97433229569
# 132367  97466325913
# 132368  97450710850
# 132369  97455631132
# 132373  97433655923
#
# [6812 rows x 1 columns]

# %% [markdown]
# Note: data will miss order rows from outlets without location data.
